# %%
import os
from dotenv import load_dotenv

import openai

# %%
load_dotenv()
openai.api_key = os.getenv('OPEN_AI_SECRET_KEY')
# openai.Model.list()

# %%
input_prompt = ""

response = openai.Image.create(
  prompt=input_prompt,
  n=1,
  size="512x512"
)
image_url = response['data'][0]['url']

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-hp3Hm4ILYJVjXlH5xATTqTW3/user-micg0N8ORelenpIWVV7q6IXb/img-o3bxXqkqVtZ7K84Yy64mImrs.png?st=2022-12-30T19%3A57%3A39Z&se=2022-12-30T21%3A57%3A39Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2022-12-30T16%3A51%3A50Z&ske=2022-12-31T16%3A51%3A50Z&sks=b&skv=2021-08-06&sig=pV8rX2hzgu/cm%2Brw0LwaNqShQAXm7Imev/zsO3mZiHo%3D'

# %%
import tensorflow as tf
import numpy as np
import matplotlib as mpl
import IPython.display as display
import PIL.Image
# Out:
# 2022-12-30 13:13:30.036785: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Download an image and read it into a NumPy array.
def download(url, max_dim=None):
  name = url.split('/')[-1]
  image_path = tf.keras.utils.get_file(name, origin=url)
  img = PIL.Image.open(image_path)
  if max_dim:
    img.thumbnail((max_dim, max_dim))
  return np.array(img)

# Display an image
def show(img):
  display.display(PIL.Image.fromarray(np.array(img)))


# Downsizing the image makes it easier to work with.
original_img = download(image_url, max_dim=500)
show(original_img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FBBCFE57CD0>
